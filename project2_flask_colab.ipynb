# %% [markdown]
# <a href="https://colab.research.google.com/github/Buji-90/project2_flask/blob/main/project2_flask_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install flask-ngrok

from flask import Flask
from flask_ngrok import run_with_ngrok

app = Flask(__name__)
run_with_ngrok(app)  # Esto activa ngrok

@app.route("/")
def home():
    return "¡Hola, mundo desde Colab!"

app.run()
